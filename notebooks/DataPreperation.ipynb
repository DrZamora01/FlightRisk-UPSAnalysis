# %%
#load raw data file
airbus_df = pd.read_csv(r"../data/raw/AIDS_REPORTS AirBus.csv")
boeings_df = pd.read_csv(r"../data/raw/AIDS_REPORTS Boeings.csv")
md11_df = pd.read_csv(r"../data/raw/AIDS_REPORTS MD_11.csv")

# %%
#filter for ups
airbus_ups = airbus_df[airbus_df['Operator'] == "UNITED PARCEL SERVICE CO"]
boeings_ups = boeings_df[boeings_df['Operator'] == "UNITED PARCEL SERVICE CO"]
md11_ups = md11_df[md11_df['Operator'] == "UNITED PARCEL SERVICE CO"]

# %%
airbus_ups["AircraftType"] = "Airbus"
boeings_ups["AircraftType"] = "Boeing"
md11_ups["AircraftType"] = "MD-11"
# Out:
# C:\Users\moonw\AppData\Local\Temp\ipykernel_30740\3685360566.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   airbus_ups["AircraftType"] = "Airbus"
# C:\Users\moonw\AppData\Local\Temp\ipykernel_30740\3685360566.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   boeings_ups["AircraftType"] = "Boeing"
# C:\Users\moonw\AppData\Local\Temp\ipykernel_30740\3685360566.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
#combined
combined_df = pd.concat([airbus_ups, boeings_ups, md11_ups], ignore_index=True)

# %%
# Drop columns that are empty or irrelevant
columns_to_drop = [' ', ' .1']
combined_df.drop(columns=columns_to_drop, axis=1, inplace=True, errors='ignore')

# %%
combined_df.to_csv("../data/processed/UPS_Incidents_Cleaned.csv", index=False)

# %%
combined_df.head()
# Out:
#   AIDS Report Number Local Event Date   Event City Event State  \
# 0    20010608013749I        08-JUN-01       NEWARK          NJ
# 1    20080516833729I        16-MAY-08        OMAHA          NE
# 2    20090316002799I        16-MAR-09  ALBUQUERQUE          NM
# 3    20090318002549I        18-MAR-09   LOUISVILLE          KY
# 4    20120822020209I        22-AUG-12   LOUISVILLE          KY
#
#                       Event Airport Event Type Aircraft Damage  \
# 0               NEWARK LIBERTY INTL   INCIDENT           MINOR
# 1                   EPPLEY AIRFIELD   INCIDENT            NONE
# 2          ALBUQUERQUE INTL SUNPORT   INCIDENT           MINOR
# 3  LOUISVILLE INTL-STANDIFORD FIELD   INCIDENT           MINOR
# 4  LOUISVILLE INTL-STANDIFORD FIELD   INCIDENT           MINOR
#
#           Flight Phase Aircraft Make Aircraft Model  ... Total Fatalities  \
# 0  LEVEL OFF TOUCHDOWN        AIRBUS           A300  ...                0
# ...

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85 entries, 0 to 84
# Data columns (total 26 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   AIDS Report Number                85 non-null     object
#  1   Local Event Date                  85 non-null     object
#  2   Event City                        83 non-null     object
#  3   Event State                       83 non-null     object
#  4   Event Airport                     79 non-null     object
#  5   Event Type                        83 non-null     object
#  6   Aircraft Damage                   56 non-null     object
#  7   Flight Phase                      83 non-null     object
#  8   Aircraft Make                     85 non-null     object
#  9   Aircraft Model                    85 non-null     object
#  10  Aircraft Series                   85 non-null     object
# ...

# %%
combined_df.dtypes
# Out:
# AIDS Report Number                   object
# Local Event Date                     object
# Event City                           object
# Event State                          object
# Event Airport                        object
# Event Type                           object
# Aircraft Damage                      object
# Flight Phase                         object
# Aircraft Make                        object
# Aircraft Model                       object
# Aircraft Series                      object
# Operator                             object
# Primary Flight Type                  object
# Flight Conduct Code                  object
# Flight Plan Filed Code               object
# Aircraft Registration Nbr            object
# Total Fatalities                      int64
# Total Injuries                        int64
# Aircraft Engine Make                 object
# Aircraft Engine Model                object
# Engine Group Code                    object
# ...

# %%
missing_percent = (combined_df.isnull().mean() * 100).round(2).sort_values(ascending=False)
missing_percent
# Out:
# Engine Group Code                   72.94
# Aircraft Engine Make                55.29
# Aircraft Engine Model               55.29
# PIC Flight Time Total Make-Model    52.94
# PIC Flight Time Total Hrs           51.76
# PIC Certificate Type                34.12
# Aircraft Damage                     34.12
# Primary Flight Type                 25.88
# Flight Plan Filed Code              23.53
# Nbr of Engines                      23.53
# Event Airport                        7.06
# Event State                          2.35
# Flight Phase                         2.35
# Event Type                           2.35
# Event City                           2.35
# Aircraft Make                        0.00
# AIDS Report Number                   0.00
# Local Event Date                     0.00
# Aircraft Model                       0.00
# Total Fatalities                     0.00
# Total Injuries                       0.00
# Flight Conduct Code                  0.00
# ...

# %%
drop = [
    'Engine Group Code',
    'Aircraft Engine Make',
    'Aircraft Engine Model',
    'Aircraft Series',     # not needed       
    'Aircraft Registration Nbr'   #  not needed
]

# %%
df_cleaned = combined_df.drop(columns=drop)
print("Before: ", combined_df.shape)
print("After: ", df_cleaned.shape)
# Out:
# Before:  (85, 26)
# After:  (85, 21)
